# %%
from matplotlib import pyplot as plt

x = [1, 1/3]
y = [1, 1/2]

for i in range(2, 50) :
    y.append(5/6*y[i-1] - 1/6*y[-2])

t = []
for i in range(50) :
    t.append(1/6 * (1/2)**i)

plt.plot(range(50), t)
plt.plot(range(50), y)
plt.legend(['y', 't'])
plt.show()
